# %%
#Question 1 part a
x=var('x')
diff(tan(x)+sqrt(sin(x)),x)
# Out:
# tan(x)^2 + 1/2*cos(x)/sqrt(sin(x)) + 1

# %%
x=var('x')
diff(sin(x),x)
# Out:
# cos(x)

# %%
#Question 1 part a
x=var('x')
f=tan(x)+sqrt(sin(x))
diff(f,x)
# Out:
# tan(x)^2 + 1/2*cos(x)/sqrt(sin(x)) + 1

# %%
#Question 1 part b
x=var('x')
g=4*x^3+x^2+35
diff(g,x)
# Out:
# 12*x^2 + 2*x

# %%
#Question 1 part b
var('x,y')
h=y*sin(x)
g=diff(h,y)
print(g)
diff(g,x)
# Out:
# sin(x)
# cos(x)

# %%
#Question 2 part a
x=var('x')
solve(x^2+5*x+6,x)
# Out:
# [x == -3, x == -2]

# %%
#Question 2 part b
x=var('x')
solve(x^3+2*x,x)
# Out:
# [x == -I*sqrt(2), x == I*sqrt(2), x == 0]

# %%
#Question 2 part b
x=var('x')
solve(x^3+2*x,x,algorithm='sympy',domain='real')
# Out:
# [x == 0]

# %%
solve?

# %%
#Question 3 part a
x=var('x')
y=function('y')(x)
DE=diff(y,x)-2*x-y
desolve(DE,[y,x])
# Out:
# -(2*(x + 1)*e^(-x) - _C)*e^x

# %%
# Here we test with plotting.
x,y=PolynomialRing(QQ,2,"Hamed").gens()
f(x,y) = y^2-y
W=plot_slope_field(f(x,y),(x,0,5),(y,-3,3))
show(W)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#Question 3 part a
x=var('x')
y=function('y')(x)
DE=diff(y,x)-(y^2-y)
desolve(DE,[y,x])
# Out:
# log(y(x) - 1) - log(y(x)) == _C + x

# %%
#Question 3 part b
x=var('x')
y=function('y')(x)
DE=diff(y,x)-tan(x+y)+1
desolve(DE,[y,x],contrib_ode=True)
# Out:
# [[x == _C - 1/2*log(t^2 + 2*t + 2) + log(t + 1), y(x) == -x + arctan(t + 1)]]

# %%
# ?desolve

# %%
#Question 3 part c
x=var('x')
y=function('y')(x)
DE=diff(y,x,x)+2*diff(y,x)+y
desolve(DE,[y,x],[0,3,pi/2,2])
# Out:
# (2*x*(2*e^(1/2*pi) - 3)/pi + 3)*e^(-x)

# %%
x=var('x')
y=function('y')(x)
DE=diff(y,x,x)+2*diff(y,x)+y
desolve(DE,[y,x])
# Out:
# (_K2*x + _K1)*e^(-x)

# %%
#Question 4 part a
x=var('x')
plot(x^3+2*x,[1,4])
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#Question 4 part a
x=var('x')
plot(sin(x)/x,[-10,10])
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f(x)=sin(x)/x
f(1)
# Out:
# sin(1)

# %%
n(f(1))
# Out:
# 0.841470984807897

# %%
#It won't work
f(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [21], in <cell line: 2>()
#       1 #It won't work
# ----> 2 f(Integer(0))
#
# File /private/var/tmp/sage-9.7-current/local/var/lib/sage/venv-python3.10.5/lib/python3.10/site-packages/sage/symbolic/expression.pyx:6182, in sage.symbolic.expression.Expression.__call__ (build/cythonized/sage/symbolic/expression.cpp:62320)()
#    6180         z^2 + x^y
#    6181     """
# -> 6182     return self._parent._call_element_(self, *args, **kwds)
#    6183
#    6184 def variables(self):
#
# File /private/var/tmp/sage-9.7-current/local/var/lib/sage/venv-python3.10.5/lib/python3.10/site-packages/sage/symbolic/callable.py:476, in CallableSymbolicExpressionRing_class._call_element_(self, _the_element, *args, **kwds)
#     474 d = dict(zip([repr(_) for _ in self.arguments()], args))
#     475 d.update(kwds)
# ...

# %%
#Question 4 part b "Incomplete"
x=var('x')
y=function('y')(x)
DE=diff(y,x,x)-diff(y,x)+y
desolve(DE,[y,x])
# Out:
# (_K2*cos(1/2*sqrt(3)*x) + _K1*sin(1/2*sqrt(3)*x))*e^(1/2*x)

# %%
#example of plotting together
x=var('x')
p0=plot(sin(x)/x,[-10,10])
p1=plot(sin(2*x)/(2*x),(x, -10, 10), thickness=3, color='red', legend_label='Sinc Function $n=1$')
p2=plot(sin(3*x)/(3*x),(x, -5, 5), thickness=3, color='blue', legend_label='Sinc Function $n=1$')
show(p0+p1+p2,gridlines=True)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
# ?plot

# %%
#Question 6 part a
s=0
for i in range (100):
    if i%2==1:
        s=s+i
print(s)
# Out:
# 2500

# %%
#Question 6 part a
s=0
for i in range (1,100,2):
        s=s+i
print(s)
# Out:
# 2500

# %%
#BTW what is the imaginary number
i^2
# Out:
# 9801

# %%
I^2
# Out:
# -1

# %%
n(sqrt(pi))
# Out:
# 1.77245385090552

# %%
#Sometimes "desolve" can't help to solve a problem. The following example won't work.
x=var ('x')
y=function('y') ( x )
DE=diff(y,x)-(sin(x)*y/x)+x
desolve(DE,[ y , x ],[1,1],contrib_ode='True')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [30], in <cell line: 5>()
#       3 y=function('y') ( x )
#       4 DE=diff(y,x)-(sin(x)*y/x)+x
# ----> 5 desolve(DE,[ y , x ],[Integer(1),Integer(1)],contrib_ode='True')
#
# File /private/var/tmp/sage-9.7-current/local/var/lib/sage/venv-python3.10.5/lib/python3.10/site-packages/sage/calculus/desolvers.py:652, in desolve(de, dvar, ics, ivar, show_method, contrib_ode, algorithm)
#     649         if str(soln).strip() == 'false':
#     650             raise NotImplementedError("Maxima was unable to solve this BVP. Remove the initial condition to get the general solution.")
# --> 652 soln=soln.sage()
#     653 if is_SymbolicEquation(soln) and soln.lhs() == dvar:
#     654     # Remark: Here we do not check that the right hand side does not depend on dvar.
# ...

# %%
# Creating a list
p=list()

# %%
p.append(2)

# %%
p
# Out:
# [2]

# %%
p.append(7)

# %%
p
# Out:
# [2, 7]

# %%
# Creating a list
pts=vector([2, 3])

# %%
p.append(pts)

# %%
p
# Out:
# [2, 7, (2, 3)]

# %%
print(p)
# Out:
# [2, 7, (2, 3)]

# %%
#Creating a Function
def f(a,b):
    f=a+b
    return f

# %%
f(5,-2)
# Out:
# 3

# %%
def allin(n):
    v=[]
    for i in range(n):
        v.append(i)
    return v

# %%
allin(9)
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
def even(n):
    v=[]
    for i in range(n):
        if i%2==1:
            v.append(i)
    return v

# %%
even(10)
# Out:
# [1, 3, 5, 7, 9]

# %%
def f(x):
    if x==0:
        f=1
    else:
        f=N(sin(x)/x)
    return f

# %%
f(1)
# Out:
# 0.841470984807897

# %%
def f(i):
    x=var('x')
    f=plot(i*cos(x))
    return f

# %%
f(.5)+f(1)+f(2)+f(3)
# Out:
# Graphics object consisting of 4 graphics primitives
